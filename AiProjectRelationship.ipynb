# %%
 import pandas as pd
print("WELCOME TO RELATIONSHIP IDENTIFICATION SYSTEM")
a=input("PLEASE ENTER  YOUR GOOD NAME")
print("welcome mr.",a)

a1=input("please enter your father name.=\n ")
b=input("please enter your mother name.=\n")
c=input("please enter your father's father name.=\n ")
d=input("please enter your father's mother name .=\n")
g=input("please enter your mother's father name.=\n")
h=input("please enter your mother's mother name.=\n ")
e1=input("Did your father have any brother.please enter yes or no.=\n")
if e1=="yes":
    e=input("please enter your father's brother name.=\n ")
    k=input("Did your father's brother is married. please enter yes or no.=\n")
    if k=="yes":
        k1=input("please enter your father's brother's wife name.=\n")
        j1=input("Did your brother have any child.please enter yes or no .=\n")
        if j1=="yes":
            j=input("please enter your father's brother's have child is male or female.=\n")
            if j=="male":
                l=input("please enter his name.=\n ")
            else:
                m=input("please enter her name.=\n")
        else:
            print("hope to have child very soon")

    else:
        print("hope  to get married soon")

else:
    print("sorry for asking") 
f=input("Did your father have any sister.please enter yes or no.=\n")
if f=="yes":
    n0=input("please enter your father's sister name.=\n ")
    n1=input("Did your father's sister is married. please enter yes or no.=\n")
    if n1=="yes":
        n1=input("please enter your father's sister husband  name.=\n")
        n2=input("Did your father's sister  have any child. please enter yes or no.=\n")
        if n2=="yes":
            n3=input("please enter your father's sister's have child is male or female.=\n")
            if n3=="male":
                n5=input("please enter his name .=\n")
            else:
                n6=input("please enter her name.=\n")
        else:
            print("hope to have child very soon")

    else:
        print("hope  to get married soon")

else:
    print("sorry for asking") 
i=input("Did your mother have have any brother . please enter yes or no.=\n ")
if i=="yes":
    i1=input("please enter your mother's brother name .=\n")
else:
    print("sorry for asking")
j=input("Did your mother have any sister .please enter yes or no.=\n")
if  j=="yes":
    j1=input("please enter your mother's sister name .=\n")
else:
    print("sorry for asking")
print("thanks Mr.",a,"for entering your familier data.=\n")

 
df = pd.DataFrame(
{
    'alphabet_no.':['a','a1','b','c','d','g','h','e1','k1','l',
                   'm','n0','n1','n5','n6','i1','j1'],
    'falmilier_position':['your name','father name ','mother name','father"s"father name','father"s" mother name',
                         'mother"s" father name','mother"s" mother name','father"s" brother name',
                         'father"s" brother"s" wife name','father"s" brother"s" male child name',
                          'father"s" brother"s" female child name','father"s" sister name','father"s" sister"s" husband name',
                          'father"s" sister"s" male child name','father"s" sister"s" female child name',
                          'mother"s" brother name','mother"s"sister name']
    
})
print(df) 
      
y=input("please enter the option shown from the alphabet_no. block to find who is realted to you in which way= ")
if y=="a1":
        print(a1,"He is your Dadddy/papa ")
elif y=="b":
            print(b"She is your mom")
elif y=="c":
            print(c,"He is your grandfather")
elif y=="d":
            print(d,"She is your grandmother")
elif y=="g":
            print(g,"He is even your maternal grandfather")
elif y=="h":
            print(h,"She is even your maternal grandmother")
elif y=="e1":
            print(e1,"he is your uncle")
elif y=="k1":
            print(k1,"She is your aunt")
elif y=="l":
            print(l,"he is your Cousin")
            
elif y=="m":
            print(m,"She is your cousin")
elif y=="n0":
            print(n0,"She is your even 2 aunt")
elif y=="n1":
            print(n1,"He is your even 2nd uncle ")
elif y=="n5":
            print(n5,"He is even 2nd cousin")
elif y=="n6":
            print(n6,"She is your 2nd cousin")
elif y=="i1":
            print(i1,"He is your maternal uncle")
elif y=="j1":
            print(j1,"She is your maternal aunt")
else:
            print("entered the wrong alphabetical_no.")
m78=input("please enter your gender. please enter male or female.=\n") 
if m78=="male":
    aaz=input("want to see some more relationship of yours. please enter yes or no =\n")

    if aaz=="yes":
        yrn=input("please enter your good name .=\n")
        print("welcome mr. ",yrn)
        m11=input("are you married. Please enter yes or no=\n")
        if m11=="yes":
            print("conngrates on having the happy life")
            w11=input("please enter the name to whom you are married =\n")
            ch12=input("Are you having any children. Please enter yes or no=\n")
            if ch12=="yes":
                ch13=input("please tell us how many children you  are having.=\n")
                print("congrates on having child/children ",ch13)
                m17=input("please tell is your child male or female.=\n")
                if  m17=="male":
                    sc=input("please enter the name of your male child.=\n")
                    m19=input("is your male  married. PLease enter yes or no.=\n")
                    if  m19=="yes":
                        wf1=input("please enter the name of your child wife  .=\n")
                        gc=input("is your child having any children. PLease enter yes or no.=\n")
                        if  gc=="yes":
                            gc1=input("How many children is your  child is having .=\n")
                            print("congrates on having child\children .=\n",gc1)
                            gcm=input("please enter the child is male or female.=\n ")
                            if  gcm=="male":
                                gcm1=input("enter the name of your child's male  child .=\n")
                            else: 
                                gcm2=input("enter the name of your child's female  child.=\n")
                        else :
                            print("Hope he will get pretty child\children")
                    else :
                         print("Hope he will get married very soon.")
                  
                else  :
                    dc2=input("please enter he name of your female child.=\n")
                    m20=input("Is ypur daughter married . Please enter yes or no.=\n ")
                if m20=="yes":
                    hs1=input("please enter the name female child  husband.=\n")
                    ch17=input("Did she got children.PLease enter yes or no.=\n")
                    if ch17=="yes":
                        dc1=input("How many children is your female child is having.=\n ")
                        print("congrates on having child\children ",gc1)
                        dcm=input("please enter the child is male or female.=\n ")
                        if dcm=="male":
                            dcm1=input("enter the name of your  female male child's child.=\n")
                        else: 
                             dcm2=input("enter the name of your female child's femlae child.=\n")
                    else:
                        print("Hope she will get pretty child\children.")   
                    
                else:
                    print("Hope she will get married very soon.")
        else:
            print("hope in future you would get awesome children.")
    else:
        print("hope you will get married very soon")

    df = pd.DataFrame(
    {
     'alphabet_no.1':['w11','sc','wf1','gcm1','gcm2','dc2','hs1','dcm1','dcm2'],
    'falmilier_position1':['To whom you are married','your  male child name','your child "s" wife name' ,
                           'your child"s" male child name','your child"s" female child name','your female child name',
                           'your female child husband name','your female"s" child male child name',
                           'your female child"s" female child name']
        
     })
    print(df)
    print("Please select those alphabet no1 numbers which you have filled or code will get wrong")
    x=input("please enter the option shown from the alphabet_no1. block to find who is realted to you in which way")
    if x=="w11":
                print(w11,"She is your wife and you are related to her as husband ")
    elif x=="sc":
                print(sc,"He is your son and you are related him as father ")
    elif x=="wf1":
                print(wfi,"She is your daughter-in-law and you are related to her as father-in-law")
    elif x=="gcm1":
                print(gcm1,"He is your grandson and you are related to as grandfather")
    elif x=="gcm2":
                print(gcm2,"She is your granddaughter and you are her's grandfather")
    elif x=="dc2":
                print(dc2,"She is your daughter and you are her father ")
    elif x=="hs1":
                print(hs1,"He is your son-in-law and you are related to him as father-in-law")
    elif x=="dcm1":
                print(dcm1,"He is your grandson and you are related to him as maternal grandfather")
    elif x=="dcm2":
                print(dcm2,"She is your granddaughter and you are related to her as maternal grandfather")
    else:
                print("Sorry entered the wrong alphabetical_no1 .")           

        
else:
    ak=input("please enter your name good name  .\n")
print("Welcome mrs./miss=",ak)
ma=input("Are you married. PLease enter yes or no=\n")
if ma=="yes":
    print("congrates on the happy marriage life")
    hs1=input("Please enter the name of your husband ")
    ch21=input("Are you having any children.Please enter yes or no. =\n")
    if ch21=="yes":
        m21=input("please tell us is your child male or female.\n")
        if m21=="male":
            m22=input("please enter the name of your child ")
            d12=input("please tell us is your child is married or unmarried.\n")
            if d12=="married":
                print("congrates on the happy married life of your" ,m22)
                wf11=input("please enter the name of the your child's' wife .\n")
                mn21=input("IS your child having any children. Please enter yes or no.\n")
                if mn21=="yes":
                    print("Congrates on having beautiful child\children.")
                    gc23=input("Please enter name of the your child's' child \n")
                else:
                    print("hope your child will have his own awesome child")  
            else:
                print("hope your child will get married very soon")
        else:
            gr21=input("please enter the name of the girl child")
            d13=input("please tell us is your  girl child is married or unmarried.\n")
            if d12=="married":
                print("congrates on the happy married life of your",gr21)
                hs34=input("please enter the name of the your  female child's' husband name .\n")
                mj21=input("IS your female child having any children. Please enter yes or no.\n")
                if mj21=="yes":
                    print("Congrates to her on having beautiful child\children.")
                    gc23=input("Please enter name of the your  female child's' child \n")
                else:
                    print("hope your child will have his own awesome child")  
            else:
                print("hope your child will get married very soon")
    else:
        print("Hope you will very soon have very gourgous child\children")
else:  
    print("hope you will get married very soon")
br21=input("Are you the only child of your parents.Please enter yes or no.=\n")
if br21=="no":
    br21=input("PLease tell us are you having brother or sister.=\n")
    if br21=="brother":
        br22=input("please enter the name of your brother.=\n")
        print("Congrates on having the  handsome brother.",br22)
        mr32=input("Is your brother married.Please enter yes or no.\n")
        if mr32=="yes":
            wf24=input("please enter the name of his wife.=\n")
            ch26=input("IS he having any child/children.please enter yes or no.=\n")
            if ch26=="yes":
                print("congrates on having awesome child.")
                ma34=input("please enter the name of the child.\n")
            else:
                print("Hope he will have awesome child")
        else:
            print("Hope  your brother will get married very soon")
    else: 
        print("Congrates on having the gourgous sister")
        ss22=input("please enter the name of your sister.=\n")
        print("Congrates on having the  gourgous.",br21)
        mr33=input("Is your sister  married.Please enter yes or no.\n")
        if mr32=="yes":
            hs29=input("please enter the name of his husband")
            ch26=input("IS she having any child/children.please enter yess or no.=\n")
            if ch26=="yes":
                ma78=input("please enter the name of the child")
            else:
                print("Hope she will have awesome child")
else:
    print("Sorry for asking")
import pandas as pd
family24_relation = {
    'alphabet_no2.':['hs1','n22','wf11','gc23','gr21','hs34','gc23','br22',
                    'wf24','ma34','ss22','hs29','ma78'],
    'falmilier_position3':['your husband name','your male child name','your male child"s" wife name',
                          'your male child"s" child name','your girl child name','your girl"s" husband name ',
                          'your girl child"s" child name',' name of your brother','name of your brother"s" wife',
                          'name of your brother"s" child','namee of your siter','name of your sister"s" busband',
                          'name of your sister"s" child']
    
}
df = pd.DataFrame(family24_relation)
print(df)
print("please select that alphbet no.3 which you have entered")
family24_relation = {
    'alphabet_no2.':['hs1','n22','wf11','gc23','gr21','hs34','gc23','br22',
                    'wf24','ma34','ss22','hs29','ma78'],
    'falmilier_position3':['your husband name','your male child name','your male child"s" wife name',
                          'your male child"s" child name','your girl child name','your girl"s" husband name ',
                          'your girl child"s" child name',' name of your brother','name of your brother"s" wife',
                          'name of your brother"s" child','namee of your siter','name of your sister"s" busband',
                          'name of your sister"s" child']
    
}
df = pd.DataFrame(family24_relation)
df



ma
print("please select that option from the alphabetno.3 .which you have entered or else the program will stop working.")
w=input("please enter the alphabet no.which you wanted to see the relation.")
if w=="hs1":
    print(hs1,"He is your husband and you are his wife.")
elif w=="m22":    
    print(m22,"He is your son and you are his mother. ")
elif w=="wf11":    
    print(wf11,"She is your daughter-in-law and tyou are her mother-in-law.")
elif w=="gc23":    
    print(gc23,"its your grandchild and your are grandmother.") 
elif w=="br22":    
    print(br22,"He is your brother and you are his sister.")
elif w=="wf24":    
    print(wf24,"She is your sister-in-law and you are also related to her in same way.")
elif w=="ma34":    
    print(ma34,"its your nephew/nice and you are related to them as aunt.")
elif w=="ss34":    
    print(ss34,"she is your sister and you are same for her also.")
elif w=="hs29":    
    print(hs29,"He is your brother in law and you are her sister in law.")  
elif w=="ma78":    
    print(ma78,"its even  your nice/nephew.")  
else:
    print("you havent choose any of the option.")
    print("Thanks for giving the details hope you would be satified with our relationship identification.")
# Out:
# WELCOME TO RELATIONSHIP IDENTIFICATION SYSTEM
